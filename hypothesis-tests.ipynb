# %% [markdown]
# # Lab: Hypothesis Testing
#
#
# ## More Sleep Always!
#
# SLEEP! It's a beautiful thing that most of us don't get enough of!  There has been a lot of research done looking the amount of sleep different people get on average.  The following is an example of one of them.
#
# In 2013, [Gallup completed their latest survey on sleep](https://news.gallup.com/poll/166553/less-recommended-amount-sleep.aspx) that shows that the average amount of sleep Americans get is 6.8 hours ($\mu = 6.8$). This seems a bit low, right? How do you think our class average in Data Science DISCOVERY compares to this? It might be less than 6.8 or it may be more than that. Let's find out if the ideal hours of sleep STAT 107 students would get is significantly different from the average amount of sleep that all Americans get reported by Gallup. For the sake of this lab, assume our survey data is a random sample from the population (Americans).
#
# Run a **hypothesis test** to find out if the data we have is significantly different from the population/Gallup poll.
#
# You need to look at the Day 1 Dataset (from the first week of class) which gives you the ideal amount of sleep Stat 107 students get each week. Here's the link (make sure to login with @illinois): https://docs.google.com/spreadsheets/d/1LB4E89GoVi5yezEfHhopbI5BMxodSG7VvoznkaAkMAQ/edit#gid=0
#
# As always, start with uploading dataset to your notebook, and import the relevant libraries to your notebook.

# %%
# Import the libraries
import pandas as pd
import random
from scipy.stats import norm

## Import your data set
df = pd.read_csv("hello.csv")
df
# Out:
#           Name                      Major School Year     Type  \
# 0         Wade           Computer Science       Other  Android
# 1        Karle                 Statistics       Other   iPhone
# 2         noor  global studies/statistics   Sophomore   iPhone
# 3     Jonathan          Political Science      Senior   iPhone
# 4        Clare                 Statistics   Sophomore   iPhone
# ..         ...                        ...         ...      ...
# 161  Stephanie          Political Science      Junior   iPhone
# 162      Cindy     biomedical engineering      Senior  Android
# 163      Talal       Information sciences   Sophomore   iPhone
# 164       John     Statistics or Business    Freshman   iPhone
# 165     Anisha                        Mcb      Junior   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 0     Windows-based computer          2.0         0         1         0
# 1    Mac OS X-based computer          1.0         0         0         0
# 2    Mac OS X-based computer          1.0         0         0         0
# 3    Mac OS X-based computer          1.0         1         1         0
# 4    Mac OS X-based computer          1.0         1         0         0
# ..                       ...          ...       ...       ...       ...
# 161  Mac OS X-based computer          NaN         1         0         0
# 162   Windows-based computer          1.0         1         0         0
# 163   Windows-based computer          1.0         0         1         0
# 164   Windows-based computer          1.0         1         0         0
# 165  Mac OS X-based computer          1.0         0         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 0               0  ...           0                 Yes
# 1               0  ...           0                 Yes
# 2               0  ...           0                  No
# 3               0  ...           0                 Yes
# 4               0  ...           0                 Yes
# ..            ...  ...         ...                 ...
# 161             0  ...           0                  No
# 162             0  ...           0                  No
# 163             0  ...           0                 Yes
# 164             0  ...           1                  No
# 165             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 0    Significant -- I am a wizard when it comes to ...                   2
# 1    Some Python -- I have had one class or written...                  20
# 2    No programming background -- is Python Taylor ...                   3
# 3    No Python, but I've done some programming in o...                   2
# 4    Some Python -- I have had one class or written...                   1
# ..                                                 ...                 ...
# 161  No programming background -- is Python Taylor ...                   1
# 162  No Python, but I've done some programming in o...                   1
# 163  No Python, but I've done some programming in o...                   0
# 164  No programming background -- is Python Taylor ...                   1
# 165  Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0              3.0       2.0             8.0          4.0
# 1              1.0       2.0             7.0         20.0
# 2              3.0       1.0             7.0         20.0
# 3              4.0       1.0             6.0         10.0
# 4              4.0       0.0             8.0         20.0
# ..             ...       ...             ...          ...
# 161            2.0       9.0             7.0         30.0
# 162            2.0       1.0             8.0          3.0
# 163            3.0       2.0             8.0         12.0
# 164            1.0       1.0             7.0         12.0
# 165            4.0       1.0             7.0          6.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 1                       24.0    Extrovert
# 2                       10.0    Introvert
# 3                        8.0    Introvert
# 4                       30.0     Ambivert
# ..                       ...          ...
# 161                     12.0    Extrovert
# 162                      8.0     Ambivert
# 163                     25.0     Ambivert
# 164                     60.0    Introvert
# 165                     15.0    Introvert
#
# [166 rows x 31 columns]

# %% [markdown]
# ## Puzzle 1: Sleep Among STAT 107 Students
#
# ### Part 1: Null and Alternative Hypothesis
# In class, we learned that the first step when doing any hypothesis test is to state the **Null Hypothesis** and **Alternative Hypothesis**.
#
# **Null Hypothesis** := The null hypothesis says that any difference between our sample and the population is small and due to chance.
#
# **Alternative Hypothesis** := The alternative hypothesis says that the differences we observe are not just due to chance.
#
# _Warning!!!_ Remember that when you are stating your hypotheses, they always include the **population parameters** such as $\mu$ not **sample parameters** $\bar{X}$.
#
# Using the Day 1 dataset and the Gallup poll, state your 2 hypotheses:

# %% [markdown]
# ### Null Hypothesis
#
# $H_0$ := *EDIT THIS to define the null hypothesis*
#
#
# ### Alternative Hypothesis
#
# $H_a$ := *EDIT THIS to define the alternative hypothesis*

# %%
# The null hypothesis is that there is no difference between the 2 different groups and they both sleep the same

# The alternative hypothesis is 6.8 hours of sleep is not what college students get on average

# %% [markdown]
# ### Part 2: P-Values:
# In lecture, Karle and Wade discussed what a **p-value** is.  We can use it to decide which hypothesis is supported by our data.
#
# Here, it will tell us the probability that we will observe the difference we observed between our sample data and the Gallup data, given that the true average hours of sleep is really 6.8 hours, as reported by Gallup.
#
# Calculate the **p-value** in the following cell:

# %%
avg= df['Hours of Sleep'].mean()
avg
# Out:
# 7.051204819277109

# %%
sd= df['Hours of Sleep'].std()
sd
# Out:
# 0.8818532793382718

# %%
se= sd/(len(df['Hours of Sleep']))**(1/2)
se
# Out:
# 0.06844508863542532

# %%
# find first your z value
z_test = (6.8-avg)/(se)
z_test
# Out:
# -3.6701657384821034

# %%
# find your p value
p_value = 2* norm.cdf(z_test)
p_value
# Out:
# 0.00024239325252541324

# %%
# == TEST CASES for Puzzle 1 ==
# - This read-only cell contains test cases for your previous cell(s).
# - If this cell runs without any errors in the output, you PASSED all test cases!
# - If this cell results errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert((z_test- 3.590265738)< 0.08), "You z statistics does not seem correct. Make sure you pick the same formula"
assert((p_value - 0.000001 < 0.0013) & (0.0002 < (p_value - 0.000001))), "You p-value statistics does not seem correct."



## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
print()
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 3: Connect the p value result with your original hypotheses :
#
# We know what the **p-value** is now! But as a data scientist, it's important to explain your results in a way that anyone (even someone who has no background in statistics) can understand. If we just said "Here is the p-value", they may be confused. We need to be more specific about our conclusion.
#
# In the following cell, delete the statements that you do not believe are true and keep the one you is correct.

# %%
# Remove the of the following lines to leave only the correct answer:

conclusion = "There is enough evidence to reject the null hypothesis. Thus, DO reject the Null"

# %%
## == TEST CASES for Puzzle 1 ==
# - This read-only cell contains test cases for your previous cell(s).
# - If this cell runs without any errors in the output, you PASSED all test cases!
# - If this cell results errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(conclusion) == 80), "Your conclusion does not seem correct. Think about more!"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Puzzle 2: Who loves sleep more?
#
# We are curious if there is a significant difference in ideal hours of sleep between introverts and ambiverts in college. We are specifically interested in whether introverts sleep **less than** ambiverts.
#
# We can investiage this using our Day 1 Dataset as well!  Here, assume that the Day 1 Dataset is a random sample taken from all college students.
#
# Do a hypothesis test to satisfy our curiosity! As awlays, first you need to state your hypotheses.

# %% [markdown]
# ### Part 1: Null and Alternative Hypothesis
#
# ### Null Hypothesis
#
# The null is that we believe that there is no difference between the amount of sleep that introverts and ambiverts get
#
# ### Alternative Hypothesis
# The alternative is that we believe that introverts sleep less than ambiverts

# %% [markdown]
# ### Part 2: P-value:
#
# Calculate your test statistic and find the p-value. Remember, we are comparing two samples now- think about how this is different from Puzzle 1 and what type of z-test to do!
#
# Find the **p-value** in the following cell:

# %%
df
# Out:
#           Name                      Major School Year     Type  \
# 0         Wade           Computer Science       Other  Android
# 1        Karle                 Statistics       Other   iPhone
# 2         noor  global studies/statistics   Sophomore   iPhone
# 3     Jonathan          Political Science      Senior   iPhone
# 4        Clare                 Statistics   Sophomore   iPhone
# ..         ...                        ...         ...      ...
# 161  Stephanie          Political Science      Junior   iPhone
# 162      Cindy     biomedical engineering      Senior  Android
# 163      Talal       Information sciences   Sophomore   iPhone
# 164       John     Statistics or Business    Freshman   iPhone
# 165     Anisha                        Mcb      Junior   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 0     Windows-based computer          2.0         0         1         0
# 1    Mac OS X-based computer          1.0         0         0         0
# 2    Mac OS X-based computer          1.0         0         0         0
# 3    Mac OS X-based computer          1.0         1         1         0
# 4    Mac OS X-based computer          1.0         1         0         0
# ..                       ...          ...       ...       ...       ...
# 161  Mac OS X-based computer          NaN         1         0         0
# 162   Windows-based computer          1.0         1         0         0
# 163   Windows-based computer          1.0         0         1         0
# 164   Windows-based computer          1.0         1         0         0
# 165  Mac OS X-based computer          1.0         0         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 0               0  ...           0                 Yes
# 1               0  ...           0                 Yes
# 2               0  ...           0                  No
# 3               0  ...           0                 Yes
# 4               0  ...           0                 Yes
# ..            ...  ...         ...                 ...
# 161             0  ...           0                  No
# 162             0  ...           0                  No
# 163             0  ...           0                 Yes
# 164             0  ...           1                  No
# 165             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 0    Significant -- I am a wizard when it comes to ...                   2
# 1    Some Python -- I have had one class or written...                  20
# 2    No programming background -- is Python Taylor ...                   3
# 3    No Python, but I've done some programming in o...                   2
# 4    Some Python -- I have had one class or written...                   1
# ..                                                 ...                 ...
# 161  No programming background -- is Python Taylor ...                   1
# 162  No Python, but I've done some programming in o...                   1
# 163  No Python, but I've done some programming in o...                   0
# 164  No programming background -- is Python Taylor ...                   1
# 165  Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0              3.0       2.0             8.0          4.0
# 1              1.0       2.0             7.0         20.0
# 2              3.0       1.0             7.0         20.0
# 3              4.0       1.0             6.0         10.0
# 4              4.0       0.0             8.0         20.0
# ..             ...       ...             ...          ...
# 161            2.0       9.0             7.0         30.0
# 162            2.0       1.0             8.0          3.0
# 163            3.0       2.0             8.0         12.0
# 164            1.0       1.0             7.0         12.0
# 165            4.0       1.0             7.0          6.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 1                       24.0    Extrovert
# 2                       10.0    Introvert
# 3                        8.0    Introvert
# 4                       30.0     Ambivert
# ..                       ...          ...
# 161                     12.0    Extrovert
# 162                      8.0     Ambivert
# 163                     25.0     Ambivert
# 164                     60.0    Introvert
# 165                     15.0    Introvert
#
# [166 rows x 31 columns]

# %%
df_introvert= df[df['Personality']=='Introvert']
df_introvert
# Out:
#                Name                                              Major  \
# 0              Wade                                   Computer Science
# 2              noor                          global studies/statistics
# 3          Jonathan                                  Political Science
# 5             Dhruv                                   Computer science
# 6              Alex                                            Physics
# 10            Taige                                          Math + CS
# 14             Gail                                        Art History
# 22             Katy                                         Statistics
# 26             Eric                                       Not sure yet
# 27             Mike                                         Statistics
# 28            Chloe                             Structural Engineering
# 29           Eugene                      Statistics + Computer Science
# 30        Folashade                                  Political Science
# 34           Jackie                                               math
# 35             Niks                   Mathematics and Computer Science
# 39           Munwon                                         Statistics
# 40           Joshua                                         undeclared
# 42           Wenxin                                         Statistics
# 43            Louie                                     CS + Astronomy
# 48          Vincent                                         Statistics
# 49             Noah                                       Econometrics
# 52   Joshua Fischer                                  Actuarial Science
# 53            Jiwon                                            CS+Stat
# 56          Kamayah                     Mathematics & Computer Science
# 60            Yijia                                         statistics
# 61            Tyler                                  actuarial science
# 68          Amartya                                       Astrophysics
# 69              NaN                                       Data Science
# 72             Isha                                         Psychology
# 74           Alexus                                   Computer Science
# 78             Andy                                   Computer Science
# 79        Tanushree                                          Astronomy
# 80           Esther                                         Statistics
# 87           Gloria                                      Communication
# 90          Stephen                      Psychology & Computer Science
# 91            Angel                                   Computer Science
# 92             Yena                                        Mathematics
# 93             Teju                    computer science and statistics
# 95           Nicole                                  Political Science
# 96           Maddie                                        Photography
# 101         Krishna                                         Statistics
# 103            Cole                                  Political Science
# 104          Eunice                                         Journalism
# 109           Andre                                  Political Science
# 111           David                                         Psychology
# 113            Alex                           Media and Cinema Studies
# 116           Julia                                         Statistics
# 117          Ashley                                  Actuarial Science
# 123         Gautham                                        Mathematics
# 126         Jaesung                                          Economics
# 134           Roman                                   Computer Science
# 138       Sanskruti                                        CS and Math
# 141            Andi  Computer Science + Statistics or Statistics ma...
# 142           Jason                                            History
# 143          Austin                   Computer Science and Linguistics
# 144           Colin            Econometrics and Quantitative Economics
# 145          Connor                                        Advertising
# 150           Brian                                  Political Science
# 164            John                             Statistics or Business
# 165          Anisha                                                Mcb
#
#     School Year     Type                 Computer  Straw Holes  Has Dogs  \
# 0         Other  Android   Windows-based computer          2.0         0
# 2     Sophomore   iPhone  Mac OS X-based computer          1.0         0
# 3        Senior   iPhone  Mac OS X-based computer          1.0         1
# 5     Sophomore  Android   Windows-based computer          1.0         0
# 6        Junior  Android   Windows-based computer          1.0         0
# 10     Freshman   iPhone   Windows-based computer          1.0         0
# 14       Senior  Android   Windows-based computer          1.0         1
# 22    Sophomore   iPhone  Mac OS X-based computer          1.0         1
# 26     Freshman   iPhone  Mac OS X-based computer          1.0         0
# 27       Junior  Android   Windows-based computer          1.0         1
# 28       Junior   iPhone  Mac OS X-based computer          1.0         0
# 29     Freshman   iPhone  Mac OS X-based computer          2.0         0
# 30    Sophomore   iPhone  Mac OS X-based computer          1.0         0
# 34    Sophomore   iPhone   Windows-based computer          2.0         1
# 35     Freshman  Android   Windows-based computer          2.0         0
# 39       Senior   iPhone   Windows-based computer          2.0         0
# 40    Sophomore   iPhone  Mac OS X-based computer          1.0         0
# 42       Senior   iPhone  Mac OS X-based computer          1.0         0
# 43     Freshman   iPhone  Mac OS X-based computer          2.0         1
# 48       Senior   iPhone  Mac OS X-based computer          1.0         1
# 49       Senior   iPhone  Mac OS X-based computer          1.0         0
# 52       Junior   iPhone  Mac OS X-based computer          2.0         0
# 53       Junior   iPhone   Windows-based computer          1.0         0
# 56       Junior   iPhone   Windows-based computer          2.0         0
# 60    Sophomore   iPhone   Windows-based computer         20.0         1
# 61     Freshman  Android   Windows-based computer          1.0         1
# 68     Freshman  Android   Windows-based computer          1.0         0
# 69        Other  Android   Windows-based computer          2.0         0
# 72     Freshman   iPhone   Windows-based computer          2.0         1
# 74     Freshman   iPhone   Windows-based computer          1.0         1
# 78     Freshman   iPhone   Windows-based computer          1.0         1
# 79     Freshman   iPhone  Mac OS X-based computer          1.0         0
# 80       Senior  Android   Windows-based computer          1.0         0
# 87       Senior   iPhone  Mac OS X-based computer          1.0         1
# 90     Freshman  Android  Mac OS X-based computer          2.0         1
# 91    Sophomore   iPhone   Windows-based computer          2.0         0
# 92     Freshman   iPhone  Mac OS X-based computer          1.0         1
# 93       Junior   iPhone  Mac OS X-based computer          1.0         1
# 95     Freshman   iPhone  Mac OS X-based computer          1.0         0
# 96    Sophomore  Android  Mac OS X-based computer          1.0         0
# 101      Junior  Android   Windows-based computer          2.0         0
# 103      Junior   iPhone  Mac OS X-based computer          1.0         1
# 104   Sophomore   iPhone  Mac OS X-based computer          2.0         0
# 109      Senior  Android   Windows-based computer          1.0         1
# 111    Freshman   iPhone  Mac OS X-based computer          2.0         1
# 113    Freshman   iPhone   Windows-based computer          2.0         1
# 116   Sophomore   iPhone  Mac OS X-based computer          1.0         0
# 117   Sophomore   iPhone  Mac OS X-based computer          1.0         1
# 123      Junior  Android   Windows-based computer          0.0         1
# 126      Senior   iPhone  Mac OS X-based computer          1.0         0
# 134    Freshman   iPhone  Mac OS X-based computer          1.0         0
# 138      Senior   iPhone  Mac OS X-based computer          1.0         1
# 141   Sophomore   iPhone   Windows-based computer          1.0         1
# 142      Senior  Android   Windows-based computer          1.0         1
# 143      Junior  Android   Windows-based computer          1.0         0
# 144      Senior   iPhone  Mac OS X-based computer          1.0         0
# 145      Junior   iPhone  Mac OS X-based computer          1.0         1
# 150      Senior   iPhone  Mac OS X-based computer          2.0         1
# 164    Freshman   iPhone   Windows-based computer          1.0         1
# 165      Junior   iPhone  Mac OS X-based computer          1.0         0
#
#      Has Cats  Has Fish  Has Chickens  ...  Has Twitch  Programmed before?  \
# 0           1         0             0  ...           0                 Yes
# 2           0         0             0  ...           0                  No
# 3           1         0             0  ...           0                 Yes
# 5           0         0             0  ...           1                 Yes
# 6           0         0             0  ...           0                 Yes
# 10          1         0             0  ...           1                 Yes
# 14          0         0             0  ...           0                 Yes
# 22          0         0             0  ...           0                 Yes
# 26          0         0             0  ...           0                  No
# 27          0         0             0  ...           0                 Yes
# 28          0         1             0  ...           0                 Yes
# 29          0         0             0  ...           0                 Yes
# 30          0         0             0  ...           0                  No
# 34          0         0             0  ...           0                 Yes
# 35          0         0             0  ...           0                 Yes
# 39          0         0             0  ...           0                 Yes
# 40          0         0             0  ...           0                 Yes
# 42          0         0             0  ...           0                 Yes
# 43          1         0             0  ...           0                 Yes
# 48          0         0             0  ...           0                  No
# 49          1         0             0  ...           0                 Yes
# 52          0         0             0  ...           0                 Yes
# 53          0         0             0  ...           0                 Yes
# 56          1         0             0  ...           0                 Yes
# 60          0         0             0  ...           0                  No
# 61          1         0             0  ...           1                 Yes
# 68          0         0             0  ...           0                 Yes
# 69          0         1             0  ...           0                 Yes
# 72          0         0             0  ...           0                 Yes
# 74          0         0             0  ...           0                  No
# 78          0         0             0  ...           0                 Yes
# 79          0         0             0  ...           0                  No
# 80          0         0             0  ...           0                 Yes
# 87          0         0             0  ...           0                  No
# 90          1         0             0  ...           1                 Yes
# 91          1         0             0  ...           0                 Yes
# 92          0         0             0  ...           0                  No
# 93          0         0             0  ...           0                 Yes
# 95          1         0             0  ...           0                  No
# 96          1         0             0  ...           0                  No
# 101         0         0             0  ...           0                 Yes
# 103         0         0             0  ...           1                 Yes
# 104         0         0             0  ...           0                 Yes
# 109         0         0             0  ...           0                 Yes
# 111         0         0             0  ...           0                  No
# 113         0         0             0  ...           0                 Yes
# 116         0         0             0  ...           0                 Yes
# 117         0         0             0  ...           0                 Yes
# 123         0         0             0  ...           0                 Yes
# 126         0         0             0  ...           1                 Yes
# 134         0         0             0  ...           0                 Yes
# 138         0         0             0  ...           0                 Yes
# 141         0         0             0  ...           1                 Yes
# 142         0         0             0  ...           1                 Yes
# 143         0         1             0  ...           1                 Yes
# 144         0         0             0  ...           0                 Yes
# 145         1         0             0  ...           0                  No
# 150         1         0             0  ...           0                  No
# 164         0         0             0  ...           1                  No
# 165         0         0             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 0    Significant -- I am a wizard when it comes to ...                   2
# 2    No programming background -- is Python Taylor ...                   3
# 3    No Python, but I've done some programming in o...                   2
# 5    Some Python -- I have had one class or written...                   0
# 6    Some Python -- I have had one class or written...                   1
# 10   Some Python -- I have had one class or written...                   4
# 14   No Python, but I've done some programming in o...                   2
# 22   No Python, but I've done some programming in o...                   1
# 26   No programming background -- is Python Taylor ...                   0
# 27   Significant -- I am a wizard when it comes to ...                   2
# 28   Some Python -- I have had one class or written...                   1
# 29   Some Python -- I have had one class or written...                   0
# 30   No programming background -- is Python Taylor ...                   0
# 34   Some Python -- I have had one class or written...                   1
# 35   Some Python -- I have had one class or written...                   1
# 39   No Python, but I've done some programming in o...                   4
# 40   Some Python -- I have had one class or written...                   1
# 42   Some Python -- I have had one class or written...                   5
# 43   Some Python -- I have had one class or written...                   1
# 48   No programming background -- is Python Taylor ...                   5
# 49   Some Python -- I have had one class or written...                   4
# 52   Some Python -- I have had one class or written...                   2
# 53   Some Python -- I have had one class or written...                   4
# 56   No Python, but I've done some programming in o...                   1
# 60   No programming background -- is Python Taylor ...                   1
# 61   Some Python -- I have had one class or written...                   2
# 68   Some Python -- I have had one class or written...                   1
# 69   Some Python -- I have had one class or written...                   1
# 72   Some Python -- I have had one class or written...                   1
# 74   No programming background -- is Python Taylor ...                   0
# 78   Some Python -- I have had one class or written...                   1
# 79   No programming background -- is Python Taylor ...                   0
# 80   Some Python -- I have had one class or written...                   2
# 87   No programming background -- is Python Taylor ...                   1
# 90   Some Python -- I have had one class or written...                   0
# 91   Some Python -- I have had one class or written...                   1
# 92   Some Python -- I have had one class or written...                   1
# 93   No Python, but I've done some programming in o...                   4
# 95   No programming background -- is Python Taylor ...                   1
# 96   No programming background -- is Python Taylor ...                   0
# 101  No Python, but I've done some programming in o...                   3
# 103  No Python, but I've done some programming in o...                   2
# 104  Some Python -- I have had one class or written...                   1
# 109  No Python, but I've done some programming in o...                   1
# 111  No programming background -- is Python Taylor ...                   0
# 113  No Python, but I've done some programming in o...                   0
# 116  No Python, but I've done some programming in o...                   2
# 117  No Python, but I've done some programming in o...                   0
# 123  Some Python -- I have had one class or written...                   3
# 126  No Python, but I've done some programming in o...                   3
# 134  Some Python -- I have had one class or written...                   0
# 138  Significant -- I am a wizard when it comes to ...                   4
# 141  Some Python -- I have had one class or written...                   2
# 142  Some Python -- I have had one class or written...                   1
# 143  Significant -- I am a wizard when it comes to ...                   2
# 144  Some Python -- I have had one class or written...                   5
# 145  No programming background -- is Python Taylor ...                   1
# 150  Some Python -- I have had one class or written...                   2
# 164  No programming background -- is Python Taylor ...                   1
# 165  Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0              3.0       2.0             8.0          4.0
# 2              3.0       1.0             7.0         20.0
# 3              4.0       1.0             6.0         10.0
# 5              3.0       2.0             6.0          4.0
# 6              0.0       2.0             6.0          2.0
# 10             3.0       0.0             6.0          6.0
# 14             3.0       2.0             7.0          8.0
# 22             2.0       1.0             8.0         25.0
# 26             2.0       2.0             7.0          4.0
# 27             3.0       2.0             7.5          3.0
# 28             7.0       0.0             8.0          6.0
# 29             2.5       NaN             7.5          5.0
# 30            10.0       2.0             6.0          4.0
# 34             2.0       5.0             8.0         14.0
# 35             3.0       0.0             7.0          4.0
# 39             6.0       1.0             7.0          8.0
# 40            20.0       3.0             8.0         15.0
# 42             3.0       0.0             8.0         10.0
# 43             2.0       2.0             8.0          2.0
# 48             4.0       2.0             8.0          5.0
# 49             3.0       1.0             7.0          7.0
# 52             1.0       2.0             5.0          2.0
# 53             5.0       1.0             7.0          1.0
# 56             4.0       0.0             7.0         25.0
# 60            10.0       1.0             6.0          2.0
# 61             3.0       3.0             8.0          5.0
# 68             3.0       1.0             7.0          4.0
# 69             2.0       2.0             8.0          2.0
# 72             3.0       1.0             8.0         15.0
# 74             5.0       4.0             6.0          7.0
# 78             2.0       1.0             8.0          3.0
# 79             6.0       1.0             5.0         25.0
# 80             4.0       3.0             6.0         10.0
# 87             2.0       5.0             5.0         20.0
# 90            10.0       0.0             7.5          2.0
# 91             5.0       1.0             5.0          4.0
# 92             3.0       1.0             6.0          5.0
# 93             3.0       1.0             8.0          8.0
# 95             4.0       2.0             7.0         12.0
# 96             1.0       0.0             8.0         10.0
# 101            5.0       1.0             6.0         27.0
# 103            4.0       1.0             6.0         11.0
# 104            3.0       2.0             6.0          6.0
# 109            1.0       1.0             7.0          4.0
# 111            4.0       1.0             8.0          4.0
# 113            0.5       1.0             6.0          3.0
# 116            3.0       1.0             7.0         30.0
# 117            4.0       0.0             6.0          8.0
# 123            5.0       1.0             7.0          4.0
# 126           12.0       2.0             7.0          5.0
# 134            3.0       1.0             7.0          2.0
# 138            4.0       1.0             7.0         15.0
# 141            1.0       1.0             6.0          3.0
# 142            1.0       1.0             7.0          2.0
# 143            3.0       1.0             7.0          2.0
# 144            2.0       2.0             8.0         12.0
# 145            2.0       2.0             6.0         10.0
# 150            5.0       2.0             6.0          4.0
# 164            1.0       1.0             7.0         12.0
# 165            4.0       1.0             7.0          6.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 2                       10.0    Introvert
# 3                        8.0    Introvert
# 5                       11.0    Introvert
# 6                       74.0    Introvert
# 10                      15.0    Introvert
# 14                       2.0    Introvert
# 22                      10.0    Introvert
# 26                       5.0    Introvert
# 27                       3.0    Introvert
# 28                       5.0    Introvert
# 29                       2.0    Introvert
# 30                       7.0    Introvert
# 34                      13.0    Introvert
# 35                      30.0    Introvert
# 39                       7.0    Introvert
# 40                      20.0    Introvert
# 42                       5.0    Introvert
# 43                       2.0    Introvert
# 48                       2.0    Introvert
# 49                       6.0    Introvert
# 52                      25.0    Introvert
# 53                       3.0    Introvert
# 56                       6.0    Introvert
# 60                       5.0    Introvert
# 61                      10.0    Introvert
# 68                       4.0    Introvert
# 69                       5.0    Introvert
# 72                      10.0    Introvert
# 74                      10.0    Introvert
# 78                       1.0    Introvert
# 79                      15.0    Introvert
# 80                       8.0    Introvert
# 87                       3.0    Introvert
# 90                       8.0    Introvert
# 91                       8.0    Introvert
# 92                      13.0    Introvert
# 93                       5.0    Introvert
# 95                      10.0    Introvert
# 96                      22.0    Introvert
# 101                     10.0    Introvert
# 103                      3.0    Introvert
# 104                      7.0    Introvert
# 109                      5.0    Introvert
# 111                      6.0    Introvert
# 113                      3.0    Introvert
# 116                     15.0    Introvert
# 117                     15.0    Introvert
# 123                      4.0    Introvert
# 126                      3.0    Introvert
# 134                      6.0    Introvert
# 138                      7.0    Introvert
# 141                     10.0    Introvert
# 142                      1.0    Introvert
# 143                      3.0    Introvert
# 144                     42.0    Introvert
# 145                     25.0    Introvert
# 150                      8.0    Introvert
# 164                     60.0    Introvert
# 165                     15.0    Introvert
#
# [60 rows x 31 columns]

# %%
mean_Introvert = df_introvert['Hours of Sleep'].mean()
print(mean_Introvert)

sd_Introvert= df_introvert['Hours of Sleep'].std()
print(sd_Introvert)
# Out:
# 6.875
# 0.9095771041943482

# %%
## Make sure your mean_Introvert; sd_Ambivert; pooled_sd; p_value names as below for the test cases
df_ambivert= df[df['Personality']=='Ambivert']

mean_ambivert= df_ambivert['Hours of Sleep'].mean()
print(mean_ambivert)

sd_Ambivert = df_ambivert['Hours of Sleep'].std()
print(sd_Ambivert)
# Out:
# 7.160919540229885
# 0.8676828701884063

# %%
se_introvert= sd_Introvert/ (len(df_introvert))**(1/2)
se_introvert
# Out:
# 0.1174258992212093

# %%
se_ambivert= sd_Ambivert/ (len(df_ambivert))**(1/2)
se_ambivert
# Out:
# 0.09302536813930255

# %%
se_difference = ((se_ambivert)**(2)+(se_introvert)**(2))**(1/2)
se_difference
# Out:
# 0.14980841406730921

# %%
p_value = (mean_Introvert - mean_ambivert)/se_difference
p_value
# Out:
# -1.9085679666925812

# %%
## == TEST CASES for Puzzle 1 ==
# - This read-only cell contains test cases for your previous cell(s).
# - If this cell runs without any errors in the output, you PASSED all test cases!
# - If this cell results errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert(mean_Introvert - 0.00001 < 6.9 ), "Your mean of Introvert does not look like correct. Make sure you correctly subset your data"
assert(sd_Ambivert- 0.00001 <0.90 ), "Your standard error of Ambivert does not look like correct. Make sure you correctly subset your data"
assert(se_difference - 0.0001 < 0.2 ), "Your standard error for the difference does not look like correct."
assert(p_value - 0.0001 < 0.03 ), "Your p-value does not look like correct. Make sure you are doing one sided test."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 3: Make a conclusion based on your p-value.
#
# We know what the **p-value** is now. So in the following cell delete the statements that you do not believe are true and keep the one you think is true.  Use 1% as your cutoff instead of 5%.

# %%
# Comennt the of the following lines to leave only the correct answer:
#conclusion = "There is enough evidence to reject the null hypothesis. Thus, DO reject the Null"
#conclusion = "We cannot infer anything!"
conclusion = "There is not enough evidence to reject the null hypothesis. Thus, DO NOT reject the Null"

# %%
## == TEST CASES for Puzzle 1 ==
# - This read-only cell contains test cases for your previous cell(s).
# - If this cell runs without any errors in the output, you PASSED all test cases!
# - If this cell results errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(conclusion) == 88), "Your conclusion does not seem correct. Think about more!"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
print()
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Puzzle 3: Halloween!
#
# ![pumpkins.jpeg](pumpkins.jpeg)
#
# Karle heard that 20% of college students dress up in the same costume for two consecutive Halloweens. However Karle thinks that this percent is higher for UIUC students!  She thinks it is **40%** and wants to test this hypothesis. She decides to take 1000 differents samples of 60 students this Hallowen.
#
# We can simulate this in Python.
#
# Can you help her simulate this and test her idea by finding an approximate p-value. As always, start with the null and alternative hypotheses!
#
# Here are the steps that can help you:
#
# 1. Consider a very large sample that can simulate an example population -- use `random.randint(...)`.
#
# 2. Randomly sample 60 students 1000 times. For each of these 1000 samples, find the percentage that plan to wear the same costume from last halloween.
#
# 3. You have 1000 different samples and sample percentages for all of them. Now think about how you can the p-value.  Hint: The p-value is the probability of getting 40% or more people wearing the same costume given the true percentage is 20%.

# %%
## Create the DataFrame of 100 samples:
def population():
    total= 0
    for i in range(60):
        if random.randint(1,60) <= 12:
            total= total + 1
    return total/60


data= []
for i in range(1000):
    data.append({'panel':population()})

df= pd.DataFrame(data)

df
# Out:
#         panel
# 0    0.200000
# 1    0.166667
# 2    0.183333
# 3    0.166667
# 4    0.183333
# ..        ...
# 995  0.250000
# 996  0.166667
# 997  0.216667
# 998  0.266667
# 999  0.216667
#
# [1000 rows x 1 columns]

# %%
observed= df.mean()

# %%
## make sure your answer is the p-value
p_value = (observed- .40)/(((.2*.8)**(1/2))/(len(df)**(1/2)))**(1/2)
p_value =p_value[0]

# %%
## == TEST CASES for Puzzle 1 ==
# - This read-only cell contains test cases for your previous cell(s).
# - If this cell runs without any errors in the output, you PASSED all test cases!
# - If this cell results errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(df) >= 1000), "You must heave at least 1000 samples"
assert(p_value <= 0.02), "Your p value does not seem correct!"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
print()
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Puzzle 4: GPA Visualization
#
# Using Wade's [Grade disparity between sections at UIUC](http://waf.cs.illinois.edu/discovery/grade_disparity_between_sections_at_uiuc/) visualization, find the average grade Wade gave to CS 225 students.
#
# You suspect Wade might not be completely honest with his grades, so you randomly survey 107 students who have taken CS 225.  The final grades the students gave you is out of 1000 points.  You have recorded the 107 student grades in `cs225-final-grades.csv`.  (*These are really 107 randomly chosen grades from CS 225 from Fall 2018.*)
#
# You find that the translation between points and grades is as follows:
#
# | Points | Grade | GPA |
# | ------ | ----- | --- |
# | 1070 - 1100 | A+ | 4.0 |
# |  930 - 1070 | A  | 4.0 |
# |  900 - 930 | A-  | 3.67 |
# |  870 - 900 | B+  | 3.33 |
# |  830 - 870 | B   | 3.0 |
# |  800 - 830 | B-  | 2.67 |
# |  770 - 800 | C+  | 2.33 |
# |  730 - 770 | C   | 2.0 |
# |  700 - 730 | C-  | 1.67 |
# |  670 - 700 | D+  | 1.33 |
# |  630 - 670 | D   | 1.0 |
# |  600 - 630 | D-  | 0.67 |
# |    0 - 600 | F  | 0 |
#
# **Hint**: You will need to process `cs225-final-grades.csv` and understand and gather data from the GPA visualization before you will be able to run the test.  Use `pandas` to help you process this data! :)

# %%
import pandas as pd
## First read the data cs225-final-grades.csv
sample_cs225 = pd.read_csv("cs225-final-grades.csv")
converted_grades= sample_cs225
converted_grades['GPA']= 0.0

## Procecess sample_cs225 to convert to GPA format. Make sure conv_sample_cs225 is a DataFrame
for i in range(107):
    if sample_cs225['CS 225 Final Grade'][i]>=1070:
        converted_grades['GPA'][i]=4.0
    elif sample_cs225['CS 225 Final Grade'][i]>=930:
        converted_grades['GPA'][i]=4.0
    elif sample_cs225['CS 225 Final Grade'][i]>=900:
        converted_grades['GPA'][i]=3.67
    elif sample_cs225['CS 225 Final Grade'][i]>=870:
        converted_grades['GPA'][i]=3.33
    elif sample_cs225['CS 225 Final Grade'][i]>=830:
        converted_grades['GPA'][i]=3.0
    elif sample_cs225['CS 225 Final Grade'][i]>=800:
        converted_grades['GPA'][i]=2.67
    elif sample_cs225['CS 225 Final Grade'][i]>=770:
        converted_grades['GPA'][i]=2.33
    elif sample_cs225['CS 225 Final Grade'][i]>=730:
        converted_grades['GPA'][i]=2.0
    elif sample_cs225['CS 225 Final Grade'][i]>=700:
        converted_grades['GPA'][i]=1.67
    elif sample_cs225['CS 225 Final Grade'][i]>=670:
        converted_grades['GPA'][i]=1.33
    elif sample_cs225['CS 225 Final Grade'][i]>=630:
        converted_grades['GPA'][i]=1.0
    elif sample_cs225['CS 225 Final Grade'][i]>=600:
        converted_grades['GPA'][i]=.67
    else: converted_grades['GPA'][i]=.00

# %%
converted_grades
# Out:
#      CS 225 Final Grade   GPA
# 0            658.204335  1.00
# 1           1068.696078  4.00
# 2           1040.655631  4.00
# 3           1047.147059  4.00
# 4            763.440841  2.00
# ..                  ...   ...
# 102          954.931372  4.00
# 103          899.918937  3.33
# 104          765.717112  2.00
# 105          328.562675  0.00
# 106         1048.897892  4.00
#
# [107 rows x 2 columns]

# %%
## == TEST CASES for Puzzle 1 ==
# - This read-only cell contains test cases for your previous cell(s).
# - If this cell runs without any errors in the output, you PASSED all test cases!
# - If this cell results errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(converted_grades[converted_grades["GPA"] == 3.67]) == 7), "Your convertion from the total points to GPA does not seem correct."
assert(len(converted_grades[converted_grades["GPA"] == 0]) == 7), "Your convertion from the total points to GPA does not seem correct."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
print()
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 1: Hypotheses
#
# Just like before, start with stating your Null and Alternative Hypotheses!
#
# ### Null Hypothesis
#
# $H_0$ := There is no difference between the grades that Wade gives and peoples actual scores
#
# ### Alternative Hypothesis
#
# $H_a$ := There is a difference between the grades and the actual scores

# %% [markdown]
# ### Part 2: P-value
# Calculate the test statistic and find the p-value in the following cell:

# %%
from scipy.stats import norm
# find first your z value
z_test = 1.50

# find your p value
p_value = .13
#norm.cdf(z_test)

# %%
# == TEST CASES for Puzzle 4 ==
# - This read-only cell contains test cases for your previous cell(s).
# - If this cell runs without any errors in the output, you PASSED all test cases!
# - If this cell results errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert(round(z_test, 2) == 1.50), "You z statistics does not seem correct. Make sure you pick the same formula"
assert(round(p_value, 2) == 0.13), "You p-value statistics does not seem correct."



## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
print()
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Submit Your Work!
#
# You're almost done -- congratulations!
#
# You need to do a few more things:
#
# 1. Save your work.  To do this, create a **notebook checkpoint** by using the menu within the notebook to go **File -> Save and Checkpoint**
#
# 2. Choose `File` and then `Close and Halt` from this notebook.
#
# 3. Choose `Quit` on the main notebook webpage.
#
# 4. Return to your command line and follow the directions on the Data Science Discovery page on how to use git to turn this notebook into the course!
